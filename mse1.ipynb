# %% [markdown]
# <a href="https://colab.research.google.com/github/LAVANYAVARANASI-123/Google-Cloud-Jam-Module-7/blob/main/mse1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/drive/MyDrive/BackOrders_Development.csv')
data
# Out:
#            sku  national_inv  lead_time  in_transit_qty  forecast_3_month  \
# 0      1682848            11       12.0               0                 0
# 1      1952807             7        4.0               0                 0
# 2      1990960             1        8.0               0                 8
# 3      3250836            36       12.0               1                 5
# 4      3275747            11        8.0               0                 0
# ...        ...           ...        ...             ...               ...
# 60584  1397275             6        8.0               0                24
# 60585  3072139           130        2.0               0                40
# 60586  1909363           135        9.0               0                 0
# 60587  1845783            63        NaN               0                 0
# 60588  1200539             0        2.0               0                 8
#
#        forecast_6_month  forecast_9_month  sales_1_month  sales_3_month  \
# ...

# %%
data.head()
# Out:
#        sku  national_inv  lead_time  in_transit_qty  forecast_3_month  \
# 0  1682848            11       12.0               0                 0
# 1  1952807             7        4.0               0                 0
# 2  1990960             1        8.0               0                 8
# 3  3250836            36       12.0               1                 5
# 4  3275747            11        8.0               0                 0
#
#    forecast_6_month  forecast_9_month  sales_1_month  sales_3_month  \
# 0                 0                 0              7             23
# 1                 0                 0              0              0
# 2                 8                 8              1              2
# 3                30                35              8             23
# 4                 6                12              1              5
#
#    sales_6_month  ...  pieces_past_due  perf_6_month_avg perf_12_month_avg  \
# ...

# %%
#Create a list with all columns of dataframe
data1=list(data.columns)
data1
# Out:
# ['sku',
#  'national_inv',
#  'lead_time',
#  'in_transit_qty',
#  'forecast_3_month',
#  'forecast_6_month',
#  'forecast_9_month',
#  'sales_1_month',
#  'sales_3_month',
#  'sales_6_month',
#  'sales_9_month',
#  'min_bank',
#  'potential_issue',
#  'pieces_past_due',
#  'perf_6_month_avg',
#  'perf_12_month_avg',
#  'local_bo_qty',
#  'deck_risk',
#  'oe_constraint',
#  'ppap_risk',
#  'stop_auto_buy',
#  'rev_stop',
#  'went_on_backorder']

# %%
#Identify Distinct Unique values present in 'went_on_backorder' with their counts #percentages.
#Also Identify Event Rate
unique_values=data['went_on_backorder'].value_counts(normalize=True)
unique_values
# Out:
# went_on_backorder
# No     0.816237
# Yes    0.183763
# Name: proportion, dtype: float64

# %%
#Sort the DataFrame using national inventory in ascending order
data=pd.read_csv('/content/drive/MyDrive/BackOrders_Development.csv')
data_sorted=data.sort_values(by='national_inv',ascending=True)
data_sorted.head()
# Out:
#            sku  national_inv  lead_time  in_transit_qty  forecast_3_month  \
# 21242  2167348         -2999        9.0               0              5809
# 4666   1963157         -2999        9.0               0              5809
# 32901  1934906         -2036        8.0              36             15000
# 41134  1692064         -1735        8.0              36             15000
# 8513   1447452         -1531        8.0              41             15000
#
#        forecast_6_month  forecast_9_month  sales_1_month  sales_3_month  \
# 21242              5809              6187              0              9
# 4666               5809              6175              3              9
# 32901             22640             31400           1594           9162
# 41134             22240             31000           2071           9508
# 8513              21640             30640           2485           9979
#
#        sales_6_month  ...  pieces_past_due  perf_6_month_avg  \
# ...

# %%
data.shape
# Out:
# (60589, 23)

# %%
data.dtypes
# Out:
# sku                    int64
# national_inv           int64
# lead_time            float64
# in_transit_qty         int64
# forecast_3_month       int64
# forecast_6_month       int64
# forecast_9_month       int64
# sales_1_month          int64
# sales_3_month          int64
# sales_6_month          int64
# sales_9_month          int64
# min_bank               int64
# potential_issue       object
# pieces_past_due        int64
# perf_6_month_avg     float64
# perf_12_month_avg    float64
# local_bo_qty           int64
# deck_risk             object
# oe_constraint         object
# ppap_risk             object
# stop_auto_buy         object
# rev_stop              object
# went_on_backorder     object
# dtype: object

# %%
data.describe()
# Out:
#                 sku   national_inv     lead_time  in_transit_qty  \
# count  6.058900e+04   60589.000000  57236.000000    60589.000000
# mean   2.036394e+06     288.261797      7.555210       30.437472
# std    6.561579e+05    4265.216529      6.485635      799.068768
# min    1.068628e+06   -2999.000000      0.000000        0.000000
# 25%    1.497628e+06       3.000000      4.000000        0.000000
# 50%    1.897487e+06      10.000000      8.000000        0.000000
# 75%    2.314114e+06      57.000000      8.000000        0.000000
# max    3.284895e+06  673445.000000     52.000000   170976.000000
#
#        forecast_3_month  forecast_6_month  forecast_9_month  sales_1_month  \
# count      6.058900e+04      6.058900e+04      6.058900e+04   60589.000000
# mean       1.708265e+02      3.178831e+02      4.575655e+02      45.077869
# std        5.329970e+03      9.854293e+03      1.431812e+04    1385.014961
# min        0.000000e+00      0.000000e+00      0.000000e+00       0.000000
# ...

# %%
# Create a Dataframe with all forecast variables
forecast_variables=data[['forecast_3_month','forecast_6_month','forecast_9_month']].copy()
forecast_variables.head()
# Out:
#    forecast_3_month  forecast_6_month  forecast_9_month
# 0                 0                 0                 0
# 1                 0                 0                 0
# 2                 8                 8                 8
# 3                 5                30                35
# 4                 0                 6                12

# %%
#Create a variable with only one column ‘went_on_backorder’
new_went_on_backorder=data[['went_on_backorder']].copy()
new_went_on_backorder
# Out:
#       went_on_backorder
# 0                    No
# 1                    No
# 2                   Yes
# 3                    No
# 4                    No
# ...                 ...
# 60584                No
# 60585                No
# 60586                No
# 60587               Yes
# 60588               Yes
#
# [60589 rows x 1 columns]

# %%
#Drop went_on_backorder from the dataframe
data.drop(columns=['went_on_backorder']).head()
# Out:
#        sku  national_inv  lead_time  in_transit_qty  forecast_3_month  \
# 0  1682848            11       12.0               0                 0
# 1  1952807             7        4.0               0                 0
# 2  1990960             1        8.0               0                 8
# 3  3250836            36       12.0               1                 5
# 4  3275747            11        8.0               0                 0
#
#    forecast_6_month  forecast_9_month  sales_1_month  sales_3_month  \
# 0                 0                 0              7             23
# 1                 0                 0              0              0
# 2                 8                 8              1              2
# 3                30                35              8             23
# 4                 6                12              1              5
#
#    sales_6_month  ...  potential_issue  pieces_past_due perf_6_month_avg  \
# ...

# %%
new_sku=data[['sku']]
new_sku.head()
# Out:
#        sku
# 0  1682848
# 1  1952807
# 2  1990960
# 3  3250836
# 4  3275747

# %%
sku_drop=data.drop(columns=['sku']).head()
sku_drop
# Out:
#    national_inv  lead_time  in_transit_qty  forecast_3_month  \
# 0            11       12.0               0                 0
# 1             7        4.0               0                 0
# 2             1        8.0               0                 8
# 3            36       12.0               1                 5
# 4            11        8.0               0                 0
#
#    forecast_6_month  forecast_9_month  sales_1_month  sales_3_month  \
# 0                 0                 0              7             23
# 1                 0                 0              0              0
# 2                 8                 8              1              2
# 3                30                35              8             23
# 4                 6                12              1              5
#
#    sales_6_month  sales_9_month  ...  pieces_past_due perf_6_month_avg  \
# 0             47             65  ...                0             0.93
# ...

# %%
#no of cols after dropping a col
sku_drop.shape[1]
# Out:
# 22

# %%
sku_drop.columns
# Out:
# Index(['national_inv', 'lead_time', 'in_transit_qty', 'forecast_3_month',
#        'forecast_6_month', 'forecast_9_month', 'sales_1_month',
#        'sales_3_month', 'sales_6_month', 'sales_9_month', 'min_bank',
#        'potential_issue', 'pieces_past_due', 'perf_6_month_avg',
#        'perf_12_month_avg', 'local_bo_qty', 'deck_risk', 'oe_constraint',
#        'ppap_risk', 'stop_auto_buy', 'rev_stop', 'went_on_backorder'],
#       dtype='object')

# %%
cate_data=data.select_dtypes(include=['object'])
cate_data.head()
# Out:
#   potential_issue deck_risk oe_constraint ppap_risk stop_auto_buy rev_stop  \
# 0              No       Yes            No        No           Yes       No
# 1              No       Yes            No        No           Yes       No
# 2              No        No            No        No           Yes       No
# 3              No        No            No       Yes           Yes       No
# 4              No        No            No        No           Yes       No
#
#   went_on_backorder
# 0                No
# 1                No
# 2               Yes
# 3                No
# 4                No

# %%
num_data=data.select_dtypes(include=['int64','float64'])
num_data.head()
# Out:
#        sku  national_inv  lead_time  in_transit_qty  forecast_3_month  \
# 0  1682848            11       12.0               0                 0
# 1  1952807             7        4.0               0                 0
# 2  1990960             1        8.0               0                 8
# 3  3250836            36       12.0               1                 5
# 4  3275747            11        8.0               0                 0
#
#    forecast_6_month  forecast_9_month  sales_1_month  sales_3_month  \
# 0                 0                 0              7             23
# 1                 0                 0              0              0
# 2                 8                 8              1              2
# 3                30                35              8             23
# 4                 6                12              1              5
#
#    sales_6_month  sales_9_month  min_bank  pieces_past_due  perf_6_month_avg  \
# ...
